# %%
import pandas as pd

# %%
pd.read_csv('Master_data.csv',encoding = "ISO-8859-1" )
# Out:
#       Library                                               Book  \
# 0   Crossword                         Ultimate Visual Dictionary
# 1   Crossword                        Operational Risk Management
# 2   Crossword                  Banking Principles and Operations
# 3   Crossword                      Financing your small Business
# 4   Crossword                                Trust based selling
# 5   Crossword                                        You can win
# 6   Crossword                               The habit of winning
# 7   Crossword               The Elements of Statistical learning
# 8   Crossword               The Elements of Statistical learning
# 9   Crossword               The Elements of Statistical learning
# 10  Crossword                    The cartoon guide to statistics
# 11  Crossword                    The cartoon guide to statistics
# 12     Granth                      Cracking the coding interview
# ...
